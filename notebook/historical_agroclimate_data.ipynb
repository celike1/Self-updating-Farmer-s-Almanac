# %%
import xarray as xr
import pandas as pd

# %%
# max/min numbers from Canadian yield data
canada_lat_min = 42
canada_lat_max = 72
canada_lon_min = -136
canada_lon_max = -55

# %%
cwd_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CWD_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
cwd_data1
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1951-04-16 1951-07-16 ... 1980-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     CWD          (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          CWD index from ECA rain indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 09:55:31 2017: cdo -f nc4c -z zip mergetime pr...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
cwd_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CWD_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
cwd_data2
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1981-04-16 1981-07-16 ... 2010-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     CWD          (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          CWD index from ECA rain indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 09:55:31 2017: cdo -f nc4c -z zip mergetime pr...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
cwd_canada1 = cwd_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
cwd_canada2 = cwd_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
cwd_df1 = cwd_canada1['CWD'].to_dataframe()
cwd_df1.dropna(inplace=True)
#cwd_df1.reset_index(inplace=True)
cwd_df2 = cwd_canada2['CWD'].to_dataframe()
cwd_df2.dropna(inplace=True)
#cwd_df2.reset_index(inplace=True)
cwd_df = pd.concat([cwd_df1, cwd_df2])
cwd_df
# Out:
#                            CWD
# time       lat   lon
# 1951-04-16 42.25 -124.25  29.0
#                  -123.75  21.0
#                  -123.25  11.0
#                  -122.75   7.0
#                  -122.25   7.0
# ...                        ...
# 2010-10-16 71.75 -73.75    8.0
#                  -72.75    4.0
#                  -72.25    4.0
#                  -55.75    5.0
#                  -55.25    5.0
#
# [1783572 rows x 1 columns]

# %%
ww_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\WW_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
ww_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\WW_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
ww_data1
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1951-04-16 1951-07-16 ... 1980-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     WW           (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          WW index from ECA compound indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 10:18:15 2017: cdo -f nc4c -z zip mergetime ta...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
ww_canada1 = ww_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
ww_canada2 = ww_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
ww_df1 = ww_canada1['WW'].to_dataframe()
ww_df1.dropna(inplace=True)
#ww_df1.reset_index(inplace=True)
ww_df2 = ww_canada2['WW'].to_dataframe()
ww_df2.dropna(inplace=True)
#ww_df2.reset_index(inplace=True)
ww_df = pd.concat([ww_df1, ww_df2])
ww_df
# Out:
#                            WW
# time       lat   lon
# 1951-04-16 42.25 -124.25  4.0
#                  -123.75  4.0
#                  -123.25  4.0
#                  -122.75  4.0
#                  -122.25  4.0
# ...                       ...
# 2010-10-16 71.75 -73.75   9.0
#                  -72.75   8.0
#                  -72.25   7.0
#                  -55.75   2.0
#                  -55.25   2.0
#
# [1783572 rows x 1 columns]

# %%
cdd_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CDD_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
cdd_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CDD_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
cdd_data1
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1951-04-16 1951-07-16 ... 1980-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     CDD          (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          CDD index from ECA drought indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 09:55:31 2017: cdo -f nc4c -z zip mergetime pr...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
cdd_canada1 = cdd_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
cdd_canada2 = cdd_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
cdd_df1 = cdd_canada1['CDD'].to_dataframe()
cdd_df1.dropna(inplace=True)
#cdd_df1.reset_index(inplace=True)
cdd_df2 = cdd_canada2['CDD'].to_dataframe()
cdd_df2.dropna(inplace=True)
#cdd_df2.reset_index(inplace=True)
cdd_df = pd.concat([cdd_df1, cdd_df2])
cdd_df
# Out:
#                            CDD
# time       lat   lon
# 1951-04-16 42.25 -124.25  25.0
#                  -123.75  25.0
#                  -123.25  25.0
#                  -122.75  14.0
#                  -122.25  14.0
# ...                        ...
# 2010-10-16 71.75 -73.75   21.0
#                  -72.75   21.0
#                  -72.25   21.0
#                  -55.75   13.0
#                  -55.25   14.0
#
# [1783572 rows x 1 columns]

# %%
csdi_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CSDI_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
csdi_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CSDI_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
csdi_data1
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1951-04-16 1951-07-16 ... 1980-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     CSDI         (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          CSDI index from ECA cold indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 10:55:59 2017: cdo -f nc4c -z zip mergetime ta...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
csdi_canada1 = csdi_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
csdi_canada2 = csdi_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
csdi_df1 = csdi_canada1['CSDI'].to_dataframe()
csdi_df1.dropna(inplace=True)
#csdi_df1.reset_index(inplace=True)
csdi_df2 = csdi_canada2['CSDI'].to_dataframe()
csdi_df2.dropna(inplace=True)
#csdi_df2.reset_index(inplace=True)
csdi_df = pd.concat([csdi_df1, csdi_df2])
csdi_df
# Out:
#                           CSDI
# time       lat   lon
# 1951-04-16 42.25 -124.25   0.0
#                  -123.75   0.0
#                  -123.25   0.0
#                  -122.75   0.0
#                  -122.25   0.0
# ...                        ...
# 2010-10-16 71.75 -73.75    0.0
#                  -72.75    0.0
#                  -72.25    0.0
#                  -55.75    0.0
#                  -55.25    0.0
#
# [1783572 rows x 1 columns]

# %%
wsdi_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\WSDI_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
wsdi_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\WSDI_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
wsdi_data1
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1951-04-16 1951-07-16 ... 1980-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     WSDI         (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          WSDI index from ECA heat indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 11:29:50 2017: cdo -f nc4c -z zip mergetime ta...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
wsdi_canada1 = wsdi_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
wsdi_canada2 = wsdi_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
wsdi_df1 = wsdi_canada1['WSDI'].to_dataframe()
wsdi_df1.dropna(inplace=True)
#wsdi_df1.reset_index(inplace=True)
wsdi_df2 = wsdi_canada2['WSDI'].to_dataframe()
wsdi_df2.dropna(inplace=True)
#wsdi_df2.reset_index(inplace=True)
wsdi_df = pd.concat([wsdi_df1, wsdi_df2])
wsdi_df
# Out:
#                           WSDI
# time       lat   lon
# 1951-04-16 42.25 -124.25   0.0
#                  -123.75   0.0
#                  -123.25   0.0
#                  -122.75   0.0
#                  -122.25   0.0
# ...                        ...
# 2010-10-16 71.75 -73.75    0.0
#                  -72.75    0.0
#                  -72.25    0.0
#                  -55.75    0.0
#                  -55.25    0.0
#
# [1783572 rows x 1 columns]

# %%
cfd_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CFD_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
cfd_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CFD_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
cfd_data1
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1951-04-16 1951-07-16 ... 1980-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     CFD          (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          CFD index from ECA cold indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 10:55:59 2017: cdo -f nc4c -z zip mergetime ta...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
cfd_canada1 = cfd_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
cfd_canada2 = cfd_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
cfd_df1 = cfd_canada1['CFD'].to_dataframe()
cfd_df1.dropna(inplace=True)
#cfd_df1.reset_index(inplace=True)
cfd_df2 = cfd_canada2['CFD'].to_dataframe()
cfd_df2.dropna(inplace=True)
#cfd_df2.reset_index(inplace=True)
cfd_df = pd.concat([cfd_df1, cfd_df2])
cfd_df
# Out:
#                            CFD
# time       lat   lon
# 1951-04-16 42.25 -124.25   1.0
#                  -123.75   4.0
#                  -123.25   4.0
#                  -122.75   4.0
#                  -122.25  12.0
# ...                        ...
# 2010-10-16 71.75 -73.75   83.0
#                  -72.75   90.0
#                  -72.25   90.0
#                  -55.75   82.0
#                  -55.25   82.0
#
# [1783572 rows x 1 columns]

# %%
csu_data1 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CSU_C3S-glob-agric_gfdl-esm2m_hist_season_19510101-19801231_v1.1.nc')
csu_data2 = xr.open_dataset(r'C:\Users\kat\Documents\School\2024-WinterB\LSI\CDS_agroclimate\CSU_C3S-glob-agric_gfdl-esm2m_hist_season_19810101-20101231_v1.1.nc')
csu_data2
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:      (time: 119, lat: 360, lon: 720, bounds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 952B 1981-04-16 1981-07-16 ... 2010-10-16
#   * lat          (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon          (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
# Dimensions without coordinates: bounds
# Data variables:
#     time_bounds  (time, bounds) datetime64[ns] 2kB ...
#     CSU          (time, lat, lon) float32 123MB ...
# Attributes: (12/14)
#     title:          CSU index from ECA heat indices
#     institution:    Copernicus Climate Change Service
#     source:         Climate projection datasets from the ISIMIP Fast Track pr...
#     references:     Tank, A.K., 2010. European Climate Assessment and Dataset...
#     comment:
#     history:        Tue Sep 19 11:29:50 2017: cdo -f nc4c -z zip mergetime ta...
#     ...             ...
#     contact:        https://climate.copernicus.eu
# ...

# %%
csu_canada1 = csu_data1.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
csu_canada2 = csu_data2.sel(lat=slice(canada_lat_min, canada_lat_max), lon=slice(canada_lon_min, canada_lon_max))
csu_df1 = csu_canada1['CSU'].to_dataframe()
csu_df1.dropna(inplace=True)
#csu_df1.reset_index(inplace=True)
csu_df2 = csu_canada2['CSU'].to_dataframe()
csu_df2.dropna(inplace=True)
#csu_df2.reset_index(inplace=True)
csu_df = pd.concat([csu_df1, csu_df2])
csu_df
# Out:
#                           CSU
# time       lat   lon
# 1951-04-16 42.25 -124.25  0.0
#                  -123.75  1.0
#                  -123.25  3.0
#                  -122.75  3.0
#                  -122.25  2.0
# ...                       ...
# 2010-10-16 71.75 -73.75   0.0
#                  -72.75   0.0
#                  -72.25   0.0
#                  -55.75   0.0
#                  -55.25   0.0
#
# [1783572 rows x 1 columns]

# %%
agroclimate_df = cwd_df.join([ww_df, cdd_df, csdi_df, wsdi_df, cfd_df, csu_df])
agroclimate_df
# Out:
#                            CWD   WW   CDD  CSDI  WSDI   CFD  CSU
# time       lat   lon
# 1951-04-16 42.25 -124.25  29.0  4.0  25.0   0.0   0.0   1.0  0.0
#                  -123.75  21.0  4.0  25.0   0.0   0.0   4.0  1.0
#                  -123.25  11.0  4.0  25.0   0.0   0.0   4.0  3.0
#                  -122.75   7.0  4.0  14.0   0.0   0.0   4.0  3.0
#                  -122.25   7.0  4.0  14.0   0.0   0.0  12.0  2.0
# ...                        ...  ...   ...   ...   ...   ...  ...
# 2010-10-16 71.75 -73.75    8.0  9.0  21.0   0.0   0.0  83.0  0.0
#                  -72.75    4.0  8.0  21.0   0.0   0.0  90.0  0.0
#                  -72.25    4.0  7.0  21.0   0.0   0.0  90.0  0.0
#                  -55.75    5.0  2.0  13.0   0.0   0.0  82.0  0.0
#                  -55.25    5.0  2.0  14.0   0.0   0.0  82.0  0.0
#
# [1783572 rows x 7 columns]

# %%
agroclimate_df.to_csv(r'historical_agroclimate_data.csv')

# %%
agroclimate_df.reset_index(inplace=True)
agroclimate_df['loc (lat,lon)'] = agroclimate_df['lat'].astype(str) + ',' + agroclimate_df['lon'].astype(str)
#agroclimate_df.drop(['lat', 'lon', 'level_0', 'index'], axis=1, inplace=True)
#agroclimate_df = agroclimate_df[(agroclimate_df['time'] >= pd.Timestamp(2008)) & (agroclimate_df['time'] <= pd.Timestamp(2010))]
#agroclimate_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 3
#       1 agroclimate_df.reset_index(inplace=True)
#       2 agroclimate_df['loc (lat,lon)'] = agroclimate_df['lat'].astype(str) + ',' + agroclimate_df['lon'].astype(str)
# ----> 3 agroclimate_df.drop(['lat', 'lon', 'level_0', 'index'], axis=1, inplace=True)
#       4 agroclimate_df = agroclimate_df[(agroclimate_df['time'] >= pd.Timestamp(2008)) & (agroclimate_df['time'] <= pd.Timestamp(2010))]
#       5 agroclimate_df
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
# ...

# %%
df = agroclimate_df
df = agroclimate_df[(agroclimate_df['time'] >= pd.Timestamp('2008-01-01')) & (agroclimate_df['time'] <= pd.Timestamp('2010-12-31'))]
df
# Out:
#               time    lat     lon   CWD   WW   CDD  CSDI  WSDI   CFD  CSU  \
# 1693644 2008-01-16  42.25 -124.25  25.0  6.0  11.0   0.0   0.0   3.0  0.0
# 1693645 2008-01-16  42.25 -123.75  12.0  9.0  11.0   0.0   0.0   7.0  0.0
# 1693646 2008-01-16  42.25 -123.25  12.0  8.0  11.0   0.0   0.0   8.0  0.0
# 1693647 2008-01-16  42.25 -122.75  11.0  6.0  13.0   0.0   0.0  24.0  0.0
# 1693648 2008-01-16  42.25 -122.25   8.0  6.0  14.0   0.0   0.0  26.0  0.0
# ...            ...    ...     ...   ...  ...   ...   ...   ...   ...  ...
# 1783567 2010-10-16  71.75  -73.75   8.0  9.0  21.0   0.0   0.0  83.0  0.0
# 1783568 2010-10-16  71.75  -72.75   4.0  8.0  21.0   0.0   0.0  90.0  0.0
# 1783569 2010-10-16  71.75  -72.25   4.0  7.0  21.0   0.0   0.0  90.0  0.0
# 1783570 2010-10-16  71.75  -55.75   5.0  2.0  13.0   0.0   0.0  82.0  0.0
# 1783571 2010-10-16  71.75  -55.25   5.0  2.0  14.0   0.0   0.0  82.0  0.0
#
#          loc (lat,lon)
# 1693644  42.25,-124.25
# 1693645  42.25,-123.75
# ...

# %%
df2 = df[(df['loc (lat,lon)'].isin(['42.25,-124.25', '42.25,-123.75', '42.25,-123.25', '42.25,-122.75', '42.25,-122.25', '42.25,-121.75', '42.25,-121.25', '42.25,-120.75', '42.25,-120.25', '42.25,-119.75']))]
df3 = df2.set_index('loc (lat,lon)')
df3.to_csv('sample_historical_agroclimate.csv')
